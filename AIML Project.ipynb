# %% [markdown]
# # Data Preprocessing

# %%
#Importing Packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading the data set
df = pd.read_csv("C:\\Users\\Harish S\\Downloads\\cancer patient data sets.csv")
df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
#Find num of rows and column
df.shape
# Out:
# (1000, 26)

# %%
#Find type of object
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Find column type 
df['Age'].dtype
# Out:
# dtype('int64')

# %%
#Extract all unique value
df['Gender'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
#Find mean
df['Age'].mean()
# Out:
# 37.174

# %%
#Find median
df['Age'].median()
# Out:
# 36.0

# %%
#Find mode
df.mode(axis=0)
# Out:
#      index Patient Id   Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1  35.0     1.0            6.0          2.0           7.0
# 1        1        P10   NaN     NaN            NaN          NaN           NaN
# 2        2       P100   NaN     NaN            NaN          NaN           NaN
# 3        3      P1000   NaN     NaN            NaN          NaN           NaN
# 4        4       P101   NaN     NaN            NaN          NaN           NaN
# ..     ...        ...   ...     ...            ...          ...           ...
# 995    995       P995   NaN     NaN            NaN          NaN           NaN
# 996    996       P996   NaN     NaN            NaN          NaN           NaN
# 997    997       P997   NaN     NaN            NaN          NaN           NaN
# 998    998       P998   NaN     NaN            NaN          NaN           NaN
# 999    999       P999   NaN     NaN            NaN          NaN           NaN
#
# ...

# %%
#Heat Map
correlation = df.corr()
sns.heatmap(data = correlation,square = True, cmap ="bwr")
plt.yticks(rotation=0)
plt.xticks(rotation=90)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#         22.5, 23.5]),
#  [Text(0.5, 0, 'index'),
#   Text(1.5, 0, 'Age'),
#   Text(2.5, 0, 'Gender'),
#   Text(3.5, 0, 'Air Pollution'),
#   Text(4.5, 0, 'Alcohol use'),
#   Text(5.5, 0, 'Dust Allergy'),
#   Text(6.5, 0, 'OccuPational Hazards'),
#   Text(7.5, 0, 'Genetic Risk'),
#   Text(8.5, 0, 'chronic Lung Disease'),
#   Text(9.5, 0, 'Balanced Diet'),
#   Text(10.5, 0, 'Obesity'),
#   Text(11.5, 0, 'Smoking'),
#   Text(12.5, 0, 'Passive Smoker'),
#   Text(13.5, 0, 'Chest Pain'),
#   Text(14.5, 0, 'Coughing of Blood'),
#   Text(15.5, 0, 'Fatigue'),
#   Text(16.5, 0, 'Weight Loss'),
#   Text(17.5, 0, 'Shortness of Breath'),
#   Text(18.5, 0, 'Wheezing'),
#   Text(19.5, 0, 'Swallowing Difficulty'),
#   Text(20.5, 0, 'Clubbing of Finger Nails'),
#   Text(21.5, 0, 'Frequent Cold'),
#   Text(22.5, 0, 'Dry Cough'),
# ...

# %%
#Finding Missing value
df.isna().any()
# Out:
# index                       False
# Patient Id                  False
# Age                         False
# Gender                      False
# Air Pollution               False
# Alcohol use                 False
# Dust Allergy                False
# OccuPational Hazards        False
# Genetic Risk                False
# chronic Lung Disease        False
# Balanced Diet               False
# Obesity                     False
# Smoking                     False
# Passive Smoker              False
# Chest Pain                  False
# Coughing of Blood           False
# Fatigue                     False
# Weight Loss                 False
# Shortness of Breath         False
# Wheezing                    False
# Swallowing Difficulty       False
# Clubbing of Finger Nails    False
# Frequent Cold               False
# Dry Cough                   False
# Snoring                     False
# Level                       False
# dtype: bool

# %%
#detect outlier
sns.boxplot(x=df['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
#Filter by Sales
filter=df['Age'].values>70
df1_outlier_rem=df[filter]
df1_outlier_rem
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 15      15       P111   73       1              5            6             6
# 126    126       P211   73       1              5            6             6
# 237    237       P311   73       1              5            6             6
# 348    348       P411   73       1              5            6             6
# 459    459       P511   73       1              5            6             6
# 570    570       P611   73       1              5            6             6
# 681    681       P711   73       1              5            6             6
# 792    792       P811   73       1              5            6             6
# 889    889         P9   73       1              5            6             6
# 903    903       P911   73       1              5            6             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# ...

# %%
filter = df['Age']<70
df_out_rem = df[filter]
sns.boxplot(x=df_out_rem['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
#linear regression
import matplotlib.pyplot as plt
from scipy import stats

x = df['Air Pollution']
y = df['chronic Lung Disease']

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
#polynomial regression
import numpy
import matplotlib.pyplot as plt

x = df['Air Pollution']
y = df['chronic Lung Disease']

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
#logistic Regression
import numpy
from sklearn import linear_model

#Reshaped for Logistic function.
x = numpy.array(df['Air Pollution']).reshape(-1,1)
y = numpy.array(df['chronic Lung Disease'])

logr = linear_model.LogisticRegression()
logr.fit(x,y)

#predict if tumor is cancerous where the size is 3.46mm:
predicted = logr.predict(numpy.array([3.46]).reshape(-1,1))
print(predicted)
